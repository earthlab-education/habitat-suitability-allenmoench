# %%
from math import floor, ceil

import cartopy.crs as ccrs
import geopandas as gpd
import hvplot.pandas
import hvplot.xarray
import numpy as np
import rioxarray as rxr
import rioxarray.merge as rxrmerge
from rioxarray.merge import merge_arrays
import skfuzzy
import xarray as xr
import matplotlib.pyplot as plt
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1004'>
#   <div id="c66ede11-fe37-488a-a721-071436a69d6f" data-root-id="p1004" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# %store -r precip_min_fuzz_ac ph_fuzz_ac precip_mean_da_ac ph_da_ac

# %%
# %store -r precip_min_fuzz_ad ph_fuzz_ad precip_mean_da_ad ph_da_ad

# %%
# %store -r precip_min_fuzz_ae ph_fuzz_ae precip_mean_da_ae ph_da_ae

# %%
# %store -r precip_min_fuzz_af ph_fuzz_af precip_mean_da_af ph_da_af

# %%
# %store -r precip_min_fuzz_bc ph_fuzz_bc precip_mean_da_bc ph_da_bc

# %%
# %store -r precip_min_fuzz_bd ph_fuzz_bd precip_mean_da_bd ph_da_bd

# %%
# %store -r precip_min_fuzz_be ph_fuzz_be precip_mean_da_be ph_da_be

# %%
# %store -r precip_min_fuzz_bf ph_fuzz_bf precip_mean_da_bf ph_da_bf

# %%
# Create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 10))  # Adjust figsize as needed

# Adjust spacing between subplots and top of figure to make room for the big title
fig.subplots_adjust(top=0.9)

# Plot 1
ph_da_ac.plot(ax=axs[0, 0])
axs[0, 0].set_title("Soil pH (60–100 cm depth)")

# Plot 2
ph_fuzz_ac.plot(ax=axs[0, 1])  # Replace with your actual data
axs[0, 1].set_title("pH Fuzzy Suitability Score")

# Plot 3
precip_mean_da_ac.plot(ax=axs[1, 0])  # Replace with your actual data
axs[1, 0].set_title("Mean Annual Precipitation in Sheyenne National Grassland")

# Plot 4
precip_min_fuzz_ac.plot(ax=axs[1, 1])  # Replace with your actual data
axs[1, 1].set_title("Minimum Precipitation Fuzzy Logic Score")

# Add one title for the entire figure
fig.suptitle("Sheyenne National Grassland Cold & Dry Scenario", fontsize=16)

plt.show()

# %%
# Create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 10))  # Adjust figsize as needed

# Adjust spacing between subplots and top of figure to make room for the big title
fig.subplots_adjust(top=0.9)

# Plot 1
ph_da_ad.plot(ax=axs[0, 0])
axs[0, 0].set_title("Soil pH (60–100 cm depth)")

# Plot 2
ph_fuzz_ad.plot(ax=axs[0, 1])  # Replace with your actual data
axs[0, 1].set_title("pH Fuzzy Suitability Score")

# Plot 3
precip_mean_da_ad.plot(ax=axs[1, 0])  # Replace with your actual data
axs[1, 0].set_title("Mean Annual Precipitation in Sheyenne National Grassland")

# Plot 4
precip_min_fuzz_ad.plot(ax=axs[1, 1])  # Replace with your actual data
axs[1, 1].set_title("Minimum Precipitation Fuzzy Logic Score")

# Add one title for the entire figure
fig.suptitle("Sheyenne National Grassland Cold & Wet Scenario", fontsize=16)

plt.show()

# %%
# Create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 10))  # Adjust figsize as needed

# Adjust spacing between subplots and top of figure to make room for the big title
fig.subplots_adjust(top=0.9)

# Plot 1
ph_da_ae.plot(ax=axs[0, 0])
axs[0, 0].set_title("Soil pH (60–100 cm depth)")

# Plot 2
ph_fuzz_ae.plot(ax=axs[0, 1])  # Replace with your actual data
axs[0, 1].set_title("pH Fuzzy Suitability Score")

# Plot 3
precip_mean_da_ae.plot(ax=axs[1, 0])  # Replace with your actual data
axs[1, 0].set_title("Mean Annual Precipitation in Sheyenne National Grassland")

# Plot 4
precip_min_fuzz_ae.plot(ax=axs[1, 1])  # Replace with your actual data
axs[1, 1].set_title("Minimum Precipitation Fuzzy Logic Score")

# Add one title for the entire figure
fig.suptitle("Sheyenne National Grassland Hot & Dry Scenario", fontsize=16)

plt.show()

# %%
# Create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 10))  # Adjust figsize as needed

# Adjust spacing between subplots and top of figure to make room for the big title
fig.subplots_adjust(top=0.9)

# Plot 1
ph_da_af.plot(ax=axs[0, 0])
axs[0, 0].set_title("Soil pH (60–100 cm depth)")

# Plot 2
ph_fuzz_af.plot(ax=axs[0, 1])  # Replace with your actual data
axs[0, 1].set_title("pH Fuzzy Suitability Score")

# Plot 3
precip_mean_da_af.plot(ax=axs[1, 0])  # Replace with your actual data
axs[1, 0].set_title("Mean Annual Precipitation in Sheyenne National Grassland")

# Plot 4
precip_min_fuzz_af.plot(ax=axs[1, 1])  # Replace with your actual data
axs[1, 1].set_title("Minimum Precipitation Fuzzy Logic Score")

# Add one title for the entire figure
fig.suptitle("Sheyenne National Grassland Hot & Wet Scenario", fontsize=16)

plt.show()

# %%
# Create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 10))  # Adjust figsize as needed

# Adjust spacing between subplots and top of figure to make room for the big title
fig.subplots_adjust(top=0.9)

# Plot 1
ph_da_bc.plot(ax=axs[0, 0])
axs[0, 0].set_title("Soil pH (60–100 cm depth)")

# Plot 2
ph_fuzz_bc.plot(ax=axs[0, 1])  # Replace with your actual data
axs[0, 1].set_title("pH Fuzzy Suitability Score")

# Plot 3
precip_mean_da_bc.plot(ax=axs[1, 0])  # Replace with your actual data
axs[1, 0].set_title("Mean Annual Precipitation in Sheyenne National Grassland")

# Plot 4
precip_min_fuzz_bc.plot(ax=axs[1, 1])  # Replace with your actual data
axs[1, 1].set_title("Minimum Precipitation Fuzzy Logic Score")

# Add one title for the entire figure
fig.suptitle("Curlew National Grassland Cold & Dry Scenario", fontsize=16)

plt.show()

# %%
# Create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 10))  # Adjust figsize as needed

# Adjust spacing between subplots and top of figure to make room for the big title
fig.subplots_adjust(top=0.9)

# Plot 1
ph_da_bd.plot(ax=axs[0, 0])
axs[0, 0].set_title("Soil pH (60–100 cm depth)")

# Plot 2
ph_fuzz_bd.plot(ax=axs[0, 1])  # Replace with your actual data
axs[0, 1].set_title("pH Fuzzy Suitability Score")

# Plot 3
precip_mean_da_bd.plot(ax=axs[1, 0])  # Replace with your actual data
axs[1, 0].set_title("Mean Annual Precipitation in Sheyenne National Grassland")

# Plot 4
precip_min_fuzz_bd.plot(ax=axs[1, 1])  # Replace with your actual data
axs[1, 1].set_title("Minimum Precipitation Fuzzy Logic Score")

# Add one title for the entire figure
fig.suptitle("Curlew National Grassland Cold & Wet Scenario", fontsize=16)

plt.show()

# %%
# Create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 10))  # Adjust figsize as needed

# Adjust spacing between subplots and top of figure to make room for the big title
fig.subplots_adjust(top=0.9)

# Plot 1
ph_da_be.plot(ax=axs[0, 0])
axs[0, 0].set_title("Soil pH (60–100 cm depth)")

# Plot 2
ph_fuzz_be.plot(ax=axs[0, 1])  # Replace with your actual data
axs[0, 1].set_title("pH Fuzzy Suitability Score")

# Plot 3
precip_mean_da_be.plot(ax=axs[1, 0])  # Replace with your actual data
axs[1, 0].set_title("Mean Annual Precipitation in Sheyenne National Grassland")

# Plot 4
precip_min_fuzz_be.plot(ax=axs[1, 1])  # Replace with your actual data
axs[1, 1].set_title("Minimum Precipitation Fuzzy Logic Score")

# Add one title for the entire figure
fig.suptitle("Curlew National Grassland Hot & Dry Scenario", fontsize=16)

plt.show()

# %%
# Create a 2x2 grid of subplots
fig, axs = plt.subplots(2, 2, figsize=(12, 10))  # Adjust figsize as needed

# Adjust spacing between subplots and top of figure to make room for the big title
fig.subplots_adjust(top=0.9)

# Plot 1
ph_da_bf.plot(ax=axs[0, 0])
axs[0, 0].set_title("Soil pH (60–100 cm depth)")

# Plot 2
ph_fuzz_bf.plot(ax=axs[0, 1])  # Replace with your actual data
axs[0, 1].set_title("pH Fuzzy Suitability Score")

# Plot 3
precip_mean_da_bf.plot(ax=axs[1, 0])  # Replace with your actual data
axs[1, 0].set_title("Mean Annual Precipitation in Sheyenne National Grassland")

# Plot 4
precip_min_fuzz_bf.plot(ax=axs[1, 1])  # Replace with your actual data
axs[1, 1].set_title("Minimum Precipitation Fuzzy Logic Score")

# Add one title for the entire figure
fig.suptitle("Curlew National Grassland Hot & Wet Scenario", fontsize=16)

plt.show()
